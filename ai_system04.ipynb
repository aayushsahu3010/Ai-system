# %% [markdown]
# # Encoder vs Decoder: BERT, GPT-2, and Gemini 2.5 Flash
#
# This notebook is designed for teaching:
#
# - **BERT** – encoder-only (understands text → embeddings)
# - **GPT-2** – decoder-only (generates text)
# - **Gemini 2.5 Flash** – used both as:
#   - an **encoder-like** model (via text embeddings)
#   - a **decoder-like** model (via text generation)
#
# Students will see side-by-side code and complete small assignments.

# %% [markdown]
# ## 0. Install Dependencies

# %%
# !pip install -q transformers torch google-generativeai

# %% [markdown]
# ## 0.1 Common Imports

# %%
from transformers import AutoTokenizer, AutoModel, AutoModelForCausalLM
import torch
import torch.nn.functional as F
import numpy as np
import pandas as pd
import google.generativeai as genai

# %% [markdown]
# ## 1. BERT – Encoder-Only Model (Understands Text)
#
# BERT reads a full sentence and converts it into a **vector representation** (embedding).
# It is **not** designed to generate new text.

# %% [markdown]
# ### 1.1 Load BERT

# %%
# Load BERT (encoder-only)
bert_name = "bert-base-uncased"
bert_tokenizer = AutoTokenizer.from_pretrained(bert_name)
bert_model = AutoModel.from_pretrained(bert_name)

print("Loaded BERT model:", bert_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Loaded BERT model: bert-base-uncased

# %% [markdown]
# ### 1.2 Encode Example Sentences
#
# We will encode two similar sentences and inspect their embeddings.

# %%
sentences_bert = [
    "I like playing football.",
    "I enjoy playing soccer."
]

# Tokenize: convert text → token IDs
encoded_bert = bert_tokenizer(
    sentences_bert,
    padding=True,
    truncation=True,
    return_tensors="pt"
)

with torch.no_grad():
    outputs_bert = bert_model(**encoded_bert)

# Take the [CLS] token embedding (position 0) as a sentence embedding
bert_cls_embeddings = outputs_bert.last_hidden_state[:, 0, :]  # [batch, hidden]

print("BERT sentence embedding shape:", bert_cls_embeddings.shape)
# Out:
# BERT sentence embedding shape: torch.Size([2, 768])

# %% [markdown]
# ### 1.3 Measure Sentence Similarity

# %%
bert_sim = F.cosine_similarity(bert_cls_embeddings[0], bert_cls_embeddings[1], dim=0)
print("Cosine similarity between the two BERT sentence embeddings:", bert_sim.item())
# Out:
# Cosine similarity between the two BERT sentence embeddings: 0.9696494936943054

# %% [markdown]
# **Discussion:**
#
# - BERT converts sentences into vectors (embeddings).
# - Similar sentences → **high cosine similarity**.
# - BERT is an **encoder**: it understands text, but does **not** generate new text with `.generate()`.

# %% [markdown]
# ## 2. GPT-2 – Decoder-Only Model (Generates Text)
#
# GPT-2 takes a **prompt** and generates a continuation by predicting the **next token**
# over and over again (autoregressive generation).

# %% [markdown]
# ### 2.1 Load GPT-2

# %%
# Load GPT-2 (decoder-only)
gpt_name = "gpt2"
gpt_tokenizer = AutoTokenizer.from_pretrained(gpt_name)
gpt_model = AutoModelForCausalLM.from_pretrained(gpt_name)

print("Loaded GPT-2 model:", gpt_name)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Loaded GPT-2 model: gpt2

# %% [markdown]
# ### 2.2 Generate Text from a Prompt

# %%
gpt_prompt = "In the future, artificial intelligence will"

# Tokenize prompt
gpt_inputs = gpt_tokenizer(gpt_prompt, return_tensors="pt")

# Generate continuation
gpt_output_ids = gpt_model.generate(
    **gpt_inputs,
    max_length=40,      # total tokens (prompt + generated)
    do_sample=False,    # deterministic
    num_beams=1
)

gpt_generated_text = gpt_tokenizer.decode(gpt_output_ids[0], skip_special_tokens=True)

print("GPT-2 PROMPT:")
print(gpt_prompt)
print("\nGPT-2 CONTINUATION:")
print(gpt_generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# GPT-2 PROMPT:
# In the future, artificial intelligence will
#
# GPT-2 CONTINUATION:
# In the future, artificial intelligence will be able to do things like search for information about people, and to do things like search for information about people.
#
# "We're going to see a lot

# %% [markdown]
# **Discussion:**
#
# - GPT-2 is a **decoder-only** language model.
# - It uses **autoregressive generation**: at each step it predicts the next token.
# - It is excellent for **chat, story generation, code generation, autocomplete**, etc.

# %% [markdown]
# ## 3. Gemini 2.5 Flash – Encoder-like and Decoder-like Behavior
#
# We will use Gemini in two ways:
#
# 1. **Encoder-like**: create embeddings and compute sentence similarity.
# 2. **Decoder-like**: generate text from a prompt.
#
# > ✅ Make sure you have a **Gemini API key** (Free Tier) from Google AI Studio.

# %% [markdown]
# ### 3.1 Configure Gemini API Key

# %%
# 👉 IMPORTANT: Replace YOUR_API_KEY_HERE with your actual Gemini API key.
genai.configure(api_key="YOUR_API_KEY_HERE")

# Load the generative model (decoder-like)
gemini_model = genai.GenerativeModel("gemini-2.5-flash")

print("Gemini model ready: gemini-2.5-flash")
# Out:
# Gemini model ready: gemini-2.5-flash

# %% [markdown]
# ### 3.2 Encoder-like: Text Embeddings and Similarity

# %%
embed_model_name = "models/text-embedding-004"

gemini_text1 = "I like playing football."
gemini_text2 = "I enjoy playing soccer."

gemini_emb1 = genai.embed_content(model=embed_model_name, content=gemini_text1)["embedding"]
gemini_emb2 = genai.embed_content(model=embed_model_name, content=gemini_text2)["embedding"]

def cosine(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

gemini_sim = cosine(gemini_emb1, gemini_emb2)
print("Gemini embedding dimension:", len(gemini_emb1))
print("Cosine similarity between the two Gemini embeddings:", gemini_sim)
# Out:
# Gemini embedding dimension: 768
# Cosine similarity between the two Gemini embeddings: 0.8197920340047521

# %% [markdown]
# ### 3.3 Decoder-like: Text Generation

# %%
gemini_prompt = "In the future, artificial intelligence will"

gemini_response = gemini_model.generate_content(gemini_prompt)

print("GEMINI PROMPT:")
print(gemini_prompt)
print("\nGEMINI CONTINUATION:")
print(gemini_response.text)
# Out:
# GEMINI PROMPT:
# In the future, artificial intelligence will
#
# GEMINI CONTINUATION:
# In the future, artificial intelligence will be **transformative**, but its exact trajectory and impact are subject to ongoing development, ethical considerations, and societal choices. Here's a breakdown of what's widely anticipated:
#
# 1.  **Become More Capable and Pervasive:**
#     *   **Smarter and More Autonomous:** AI will continue to improve its ability to learn, reason, and make decisions, often without human intervention. This will range from highly specialized narrow AI to more general-purpose systems.
#     *   **Better Understanding of Context and Nuance:** Current AI often struggles with genuine understanding. Future AI will likely develop a deeper grasp of human language, emotion, and complex social contexts, leading to more natural and helpful interactions.
#     *   **Embodied AI:** AI will be increasingly integrated into physical robots, drones, and autonomous vehicles, allowing it to interact with the physical world in more sophisticated ways.
#
# 2.  **Transform Industries and Work:**
#     *   **Automation of Routine Tasks:** Many repetitive cognitive and manual tasks across all sectors (manufacturing, administration, logistics, customer service) will be automated, leading to significant shifts in the job market.
#     *   **Augmentation of Human Capabilities:** AI will serve as a powerful "copilot" for professionals in fields like medicine, law, engineering, and creative arts, enhancing productivity, accuracy, and innovation. It will help analyze vast datasets, generate ideas, and perform complex simulations.
#     *   **Creation of New Jobs and Industries:** While some jobs will be displaced, AI will also drive the creation of entirely new roles related to AI development, maintenance, ethics, and human-AI collaboration.
#     *   **Hyper-Personalization:** From education and healthcare to entertainment and shopping, AI will tailor experiences to individual needs and preferences with unprecedented precision.
#
# 3.  **Revolutionize Science and Research:**
#     *   **Accelerated Discovery:** AI will drastically speed up scientific research by identifying patterns in massive datasets, designing experiments, formulating hypotheses, and discovering new materials, drugs, and treatments.
#     *   **Complex System Modeling:** AI will be crucial for understanding and modeling complex systems like climate change, financial markets, and biological networks.
#
# 4.  **Integrate Seamlessly into Our Environments:**
#     *   **Smart Cities and Infrastructure:** AI will manage traffic flow, optimize energy consumption, improve public safety, and enhance the efficiency of urban services.
#     *   **Ambient Intelligence:** AI will become less visible and more integrated into our homes, devices, and public spaces, anticipating needs and providing assistance without explicit commands.
#
# 5.  **Enable New Forms of Creativity and Expression:**
#     *   AI will continue to push boundaries in generating art, music, literature, and design, not just as tools but as creative partners or even independent creators, challenging our understanding of authorship and originality.
#
# **Challenges and Considerations:**
#
# *   **Artificial General Intelligence (AGI) and Superintelligence (ASI):** The ultimate goal for some researchers is AGI (AI with human-level intelligence across many domains) and eventually ASI (AI surpassing human intelligence). The timeline and feasibility of these are highly debated, but if achieved, they would represent a profound shift for humanity.
# *   **Ethical Dilemmas:** Issues of bias in algorithms, privacy, accountability for AI decisions, and the potential for misuse (e.g., autonomous weapons, surveillance) will become even more pressing.
# *   **Job Displacement and Economic Inequality:** Society will need robust strategies for retraining workers, ensuring fair distribution of AI's economic benefits, and addressing potential increases in inequality.
# *   **Control and Safety:** Ensuring that advanced AI systems remain aligned with human values and goals, and don't pose existential risks, is a critical area of research and policy.
# *   **Misinformation and Manipulation:** AI's ability to generate realistic fake content (deepfakes) and engage in persuasive communication could amplify misinformation and make it harder to distinguish reality.
#
# **Ultimately, the future of artificial intelligence will be a co-creation between the technology itself and how humanity chooses to develop, regulate, and integrate it into society. It holds immense promise for solving some of the world's most pressing problems, but also significant challenges that require careful consideration and global cooperation.**

# %% [markdown]
# **Discussion:**
#
# - `text-embedding-004` turns text into vectors → encoder-like behavior.
# - `gemini-2.5-flash` generates text from a prompt → decoder-like behavior.

# %% [markdown]
# ### 4.1 Unified Helper Functions
#
# These small helpers make it easy to compare encoder vs decoder behavior across models.

# %%
def bert_encode(sentence: str):
    tokens = bert_tokenizer(sentence, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        out = bert_model(**tokens)
    return out.last_hidden_state[:, 0, :].squeeze(0)  # CLS embedding

def gpt_generate(prompt: str, max_length: int = 40):
    tokens = gpt_tokenizer(prompt, return_tensors="pt")
    out_ids = gpt_model.generate(**tokens, max_length=max_length, do_sample=False)
    return gpt_tokenizer.decode(out_ids[0], skip_special_tokens=True)

def gemini_embed(sentence: str):
    return genai.embed_content(model="models/text-embedding-004", content=sentence)["embedding"]

def gemini_generate(prompt: str):
    resp = gemini_model.generate_content(prompt)
    return resp.text

# %% [markdown]
# ### 4.2 Try All Three Models on Similar Tasks

# %%
s1 = "I love learning about transformers."
s2 = "I enjoy studying deep learning models."

print("=== BERT similarity ===")
b1 = bert_encode(s1)
b2 = bert_encode(s2)
print("Cosine similarity:", F.cosine_similarity(b1, b2, dim=0).item())

print("\n=== Gemini similarity ===")
g1 = gemini_embed(s1)
g2 = gemini_embed(s2)
print("Cosine similarity:", cosine(g1, g2))

print("\n=== GPT-2 generation ===")
print(gpt_generate("Explain transformers in simple words:"))

print("\n=== Gemini generation ===")
print(gemini_generate("Explain transformers in simple words:"))
# Out:
# === BERT similarity ===
# Cosine similarity: 0.9562077522277832
#
# === Gemini similarity ===
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Cosine similarity: 0.6452502103229109
#
# === GPT-2 generation ===
# Explain transformers in simple words:
#
# The following code is a simple example of a transformer.
#
# import { transformers } from './transformers'; import { transformers.
#
# === Gemini generation ===
# Imagine you're reading a really long sentence.
#
# **The Old Way (before Transformers):**
# Older computer models would read sentences word by word, like a child sounding out words. "The... quick... brown... fox..." By the time they got to the end, they often forgot what was at the beginning, making it hard to understand the full meaning, especially in long sentences.
#
# **The Transformer Way:**
#
# 1.  **Read Everything At Once:** Instead of reading word by word, a Transformer reads the **entire sentence (or a large chunk of it) all at once**. It takes in all the words simultaneously.
#
# 2.  **"Pay Attention" (The Magic Part):** This is the core trick. For *each word* in the sentence, the Transformer asks: "Which other words in this sentence are most important for understanding *this particular word* right now?"
#
#     *   **Example:** In the sentence "The animal didn't cross the street because it was too **tired**," the Transformer would know that "it" refers to "the animal."
#     *   **Another Example:** In "The animal didn't cross the street because **it** was too wide," the Transformer would know that "it" refers to "the street."
#
#     It does this by creating a "web of connections" or "importance scores" between every word and every other word. It literally *pays attention* to the relevant parts of the sentence to understand context.
#
# 3.  **Process in Parallel:** Because it can look at all the words and their relationships at the same time, it can process information much, much faster than older models that had to go step-by-step.
#
# **Think of it like this:**
#
# Imagine you have a team of very smart editors. Instead of one editor reading line by line, this team divides up the text. Each editor focuses on a single word, but constantly consults with *all the other editors* about their words to understand the whole meaning and how everything connects. This allows them to grasp complex ideas and long sentences much better and quicker.
#
# **In simple words:**
#
# Transformers are powerful AI models that are incredibly good at understanding sequences of information (especially language) by smartly **"paying attention"** to how every part relates to every other part, allowing for deeper context and faster processing.
#
# This "attention" mechanism is why they've revolutionized areas like:
#
# *   **Translation** (e.g., Google Translate)
# *   **Chatbots** (e.g., ChatGPT)
# *   **Summarizing text**
# *   **Answering questions**
# *   **Generating human-like text**

# %% [markdown]
# ## 5. Student Assignments (Approx. 30–40 Minutes)
#
# These tasks help you explore encoder vs decoder behavior across all three systems.

# %% [markdown]
# ### 🧩 Task 1 – BERT: Three-Sentence Similarity
#
# Use all three models to compare the following three sentences:
#
# 1. `I like playing football.`
# 2. `I enjoy playing soccer.`
# 3. `The stock market is down today.`
#
# **Your tasks:**
#
# - Compute cosine similarity for all pairs: (1,2), (1,3), (2,3).
# - Print the values clearly.
# - In 3–4 lines, explain which sentences are semantically closest and why.

# %%
# TODO: Student code for Task 1 – BERT three-sentence similarity
sentences_bert = [
    "I like playing football.",
    "I enjoy playing soccer.",
    "The stock market is down today"
]

# Tokenize: convert text → token IDs
encoded_bert = bert_tokenizer(
    sentences_bert,
    padding=True,
    truncation=True,
    return_tensors="pt"
)

with torch.no_grad():
    outputs_bert = bert_model(**encoded_bert)

# Take the [CLS] token embedding (position 0) as a sentence embedding
bert_cls_embeddings = outputs_bert.last_hidden_state[:, 0, :]  # [batch, hidden]

print("BERT sentence embedding shape:", bert_cls_embeddings.shape)

# Write your explanation in a markdown cell after running this code.
# Out:
# BERT sentence embedding shape: torch.Size([3, 768])

# %%
sim = F.cosine_similarity(bert_cls_embeddings[0], bert_cls_embeddings[1], dim=0)
print("pair(0,1): \n")
print("Cosine similarity between the two sentences:", sim.item())
# Out:
# pair(0,1):
#
# Cosine similarity between the two sentences: 0.969649612903595

# %%
sim = F.cosine_similarity(bert_cls_embeddings[1], bert_cls_embeddings[2], dim=0)
print("pair(1,2): \n")
print("Cosine similarity between the two sentences:", sim.item())
# Out:
# pair(1,2):
#
# Cosine similarity between the two sentences: 0.8546391129493713

# %%
sim = F.cosine_similarity(bert_cls_embeddings[0], bert_cls_embeddings[2], dim=0)
print("pair(0,2): \n")
print("Cosine similarity between the two sentences:", sim.item())
# Out:
# pair(0,2):
#
# Cosine similarity between the two sentences: 0.8786798715591431

# %% [markdown]
# Pair (0, 1): Cosine similarity between I like playing football. and I enjoy playing soccer.: ~0.97
#
# Pair (1, 2): Cosine similarity between I enjoy playing soccer. and The stock market is down today: ~0.8546
#
# Pair (0, 2): Cosine similarity between I like playing football. and The stock market is down today: ~0.878

# %% [markdown]
# ### 🧩 Task 2 – GPT-2: Prompt Style and Continuation
#
# Run GPT-2 with the following prompts (or your own creative ones):
#
# 1. `Machine learning is transforming healthcare by`
# 2. `Once upon a time in a distant galaxy,`
#
# **Your tasks:**
#
# - Generate up to 40 tokens for each prompt.
# - Compare the two outputs:
#   - How does GPT-2 adapt to the style/topic of each prompt?
#   - Write 4–5 lines of observations.

# %%
# TODO: Student code for Task 2 – GPT-2 generation with different prompts
gpt_prompt = "Machine learning is transforming healthcare by"

# Tokenize prompt
gpt_inputs = gpt_tokenizer(gpt_prompt, return_tensors="pt")

# Generate continuation
gpt_output_ids = gpt_model.generate(
    **gpt_inputs,
    max_length=40,      # total tokens (prompt + generated)
    do_sample=False,    # deterministic
    num_beams=1
)

gpt_generated_text = gpt_tokenizer.decode(gpt_output_ids[0], skip_special_tokens=True)

print("GPT-2 PROMPT:")
print(gpt_prompt)
print("\nGPT-2 CONTINUATION:")
print(gpt_generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# GPT-2 PROMPT:
# Machine learning is transforming healthcare by
#
# GPT-2 CONTINUATION:
# Machine learning is transforming healthcare by providing a new way to understand and predict the health of patients.
#
# The new technology is called "deep learning," and it's being used to train doctors and nurses

# %%
# TODO: Student code for Task 2 – GPT-2 generation with different prompts
gpt_prompt = "Once upon a time in a distant galaxy"

# Tokenize prompt
gpt_inputs = gpt_tokenizer(gpt_prompt, return_tensors="pt")

# Generate continuation
gpt_output_ids = gpt_model.generate(
    **gpt_inputs,
    max_length=50,      # total tokens (prompt + generated)
    do_sample=False,    # deterministic
    num_beams=1
)

gpt_generated_text = gpt_tokenizer.decode(gpt_output_ids[0], skip_special_tokens=True)

print("GPT-2 PROMPT:")
print(gpt_prompt)
print("\nGPT-2 CONTINUATION:")
print(gpt_generated_text)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# GPT-2 PROMPT:
# Once upon a time in a distant galaxy
#
# GPT-2 CONTINUATION:
# Once upon a time in a distant galaxy, the galaxy was a vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast, vast

# %% [markdown]
# ### 🧩 Task 3 – Gemini: Embeddings and Generation
#
# Repeat Tasks 1 and 2 using **Gemini**:
#
# 1. Use `text-embedding-004` to compute embeddings for the same three sentences from Task 1.
# 2. Compute cosine similarity for all pairs.
# 3. Use `gemini-2.5-flash` to generate text for the same prompts from Task 2.
#
# **Your tasks:**
#
# - Compare the Gemini similarities with BERT similarities.
# - Compare Gemini generations with GPT-2 generations.
# - Write 6–8 lines summarizing similarities and differences.

# %%
embed_model_name = "models/text-embedding-004"

gemini_text1 = "I like playing football."
gemini_text2 = "I enjoy playing soccer."
gemini_text3 = "The stock market is down today."

gemini_emb1 = genai.embed_content(model=embed_model_name, content=gemini_text1)["embedding"]
gemini_emb2 = genai.embed_content(model=embed_model_name, content=gemini_text2)["embedding"]
gemini_emb3 =   genai.embed_content(model=embed_model_name, content=gemini_text3)["embedding"]

def cosine(a, b):
    a = np.array(a)
    b = np.array(b)
    return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))

gemini_sim = cosine(gemini_emb1, gemini_emb2)
print("Gemini embedding dimension:", len(gemini_emb1))
print("Cosine similarity between the two Gemini embeddings:", gemini_sim)
# Out:
# Gemini embedding dimension: 768
# Cosine similarity between the two Gemini embeddings: 0.8197920340047521

# %%
gemini_sim = cosine(gemini_emb1, gemini_emb2)
print("Gemini embedding dimension:", len(gemini_emb1))
print("Cosine similarity between the two Gemini embeddings gemini_text1 and  gemini_text2 :", gemini_sim)
# Out:
# Gemini embedding dimension: 768
# Cosine similarity between the two Gemini embeddings gemini_text1 and  gemini_text2 : 0.8197920340047521

# %%
gemini_sim = cosine(gemini_emb2, gemini_emb3)
print("Gemini embedding dimension:", len(gemini_emb1))
print("Cosine similarity between the two Gemini embeddings gemini_text2 and  gemini_text3 :", gemini_sim)
# Out:
# Gemini embedding dimension: 768
# Cosine similarity between the two Gemini embeddings gemini_text2 and  gemini_text3 : 0.26086988066268707

# %%
gemini_sim = cosine(gemini_emb1, gemini_emb3)
print("Gemini embedding dimension:", len(gemini_emb1))
print("Cosine similarity between the two Gemini embeddings gemini_text1 and  gemini_text3 :", gemini_sim)
# Out:
# Gemini embedding dimension: 768
# Cosine similarity between the two Gemini embeddings gemini_text1 and  gemini_text3 : 0.289561688143993

# %%
gemini_prompt = "Machine learning is transforming healthcare by"

gemini_response = gemini_model.generate_content(gemini_prompt)

print("GEMINI PROMPT:")
print(gemini_prompt)
print("\nGEMINI CONTINUATION:")
print(gemini_response.text)
# Out:
# GEMINI PROMPT:
# Machine learning is transforming healthcare by
#
# GEMINI CONTINUATION:
# Machine learning is transforming healthcare by **revolutionizing virtually every aspect of the industry**, from diagnosis and treatment to drug discovery and operational efficiency. Here are the key ways:
#
# 1.  **Enabling Earlier and More Accurate Diagnosis:**
#     *   **Image Recognition:** ML algorithms can analyze medical images (X-rays, MRIs, CT scans, pathology slides, dermatological images) with high accuracy, often surpassing human capabilities in detecting subtle patterns indicative of diseases like cancer, diabetic retinopathy, and glaucoma years earlier.
#     *   **Pattern Recognition in EHRs:** By sifting through vast amounts of electronic health record (EHR) data, ML can identify complex patterns and correlations that might indicate a higher risk for certain conditions, leading to proactive interventions.
#
# 2.  **Personalizing Treatment Plans (Precision Medicine):**
#     *   **Genomic Analysis:** ML can analyze an individual's genetic profile (genomics, proteomics) alongside their medical history, lifestyle, and environmental factors to predict disease risk, drug efficacy, and potential adverse reactions. This allows for highly tailored treatments.
#     *   **Predicting Treatment Response:** Algorithms can predict how a patient will respond to different therapies based on their unique characteristics, helping clinicians choose the most effective treatment with fewer trial-and-error attempts.
#
# 3.  **Accelerating Drug Discovery and Development:**
#     *   **Target Identification:** ML can analyze biological data to identify potential drug targets (molecules or pathways involved in disease) more efficiently.
#     *   **Compound Screening:** It can rapidly screen vast libraries of chemical compounds to identify those with the highest potential therapeutic value, significantly reducing the time and cost associated with traditional methods.
#     *   **Predicting Toxicity and Efficacy:** ML models can predict a compound's potential toxicity and efficacy in humans much earlier in the development process, reducing failures in clinical trials.
#     *   **Drug Repurposing:** Identifying new uses for existing drugs.
#
# 4.  **Enhancing Predictive Analytics for Disease Prevention and Outbreaks:**
#     *   **Risk Assessment:** ML can identify individuals at high risk for developing chronic diseases (e.g., heart disease, diabetes) by analyzing their health data, lifestyle, and social determinants of health.
#     *   **Outbreak Prediction:** By analyzing data from various sources (social media, travel patterns, weather, public health reports), ML can help predict the spread of infectious diseases and inform public health responses.
#
# 5.  **Optimizing Operational Efficiency and Resource Management:**
#     *   **Workflow Optimization:** ML can analyze patient flow, appointment scheduling, and resource allocation (beds, staff, equipment) to improve efficiency, reduce wait times, and minimize operational costs for hospitals and clinics.
#     *   **Predictive Maintenance:** Monitoring medical equipment to predict failures before they occur, ensuring optimal functionality and patient safety.
#
# 6.  **Revolutionizing Patient Engagement and Remote Monitoring:**
#     *   **Wearable Data Analysis:** ML can interpret data from wearable devices (smartwatches, fitness trackers) to monitor vital signs, activity levels, sleep patterns, and detect anomalies that might require medical attention.
#     *   **AI-Powered Chatbots and Virtual Assistants:** Providing patients with immediate answers to health questions, symptom assessment, medication reminders, and mental health support, improving access to information and care.
#     *   **Telemedicine Enhancement:** ML can help triage patients in telemedicine settings, ensuring those with more urgent needs are prioritized.
#
# 7.  **Automating Repetitive Tasks and Reducing Administrative Burden:**
#     *   **Clinical Documentation:** Natural Language Processing (NLP), a subfield of AI, can automate the extraction of key information from clinical notes and generate summaries, reducing the time clinicians spend on administrative tasks.
#     *   **Billing and Coding:** Automating complex medical coding and billing processes, reducing errors and improving financial efficiency.
#
# In essence, machine learning is making healthcare more **data-driven, precise, personalized, efficient, and accessible**, ultimately leading to better patient outcomes and a more sustainable healthcare system.

# %%
gemini_prompt = "Once upon a time in a distant galaxy,"

gemini_response = gemini_model.generate_content(gemini_prompt)

print("GEMINI PROMPT:")
print(gemini_prompt)
print("\nGEMINI CONTINUATION:")
print(gemini_response.text)
# Out:
# GEMINI PROMPT:
# Once upon a time in a distant galaxy,
#
# GEMINI CONTINUATION:
# Once upon a time in a distant galaxy, nestled within a nebula that shimmered with the colors of a thousand sunsets, lay the planet of Aethelgard. Aethelgard was not merely a world; it was a living jewel, its surface crisscrossed by rivers of liquid starlight and dotted with cities built into gigantic, bioluminescent crystals that pulsed with an internal, gentle light. Its inhabitants, the Aethelans, were a species of sentient light-weavers, beings composed of shimmering energy, capable of manipulating electromagnetic fields and communicating through complex patterns of light and color. They were renowned throughout the sector for their unparalleled wisdom, their intricate star-maps etched into the very fabric of spacetime, and their profound connection to the cosmic symphony.
#
# For millennia, Aethelgard had thrived, a beacon of peace and knowledge. Its primary function was to maintain the Grand Cosmic Archive, a vast, interwoven network of quantum entanglement fields that preserved the history, wisdom, and very consciousness of countless civilizations across the galaxy. The Archive was housed within the planet's core, an immense, crystalline library humming with an almost divine energy.
#
# But even in such a utopian existence, shadows could lengthen. A chilling prophecy, whispered through the light-patterns of ancient Aethelan elders, spoke of the "Great Silence," a cosmic phenomenon that would seek to extinguish all light, all knowledge, all memory from the galaxy. Most Aethelans dismissed it as an old myth, a cautionary tale from less enlightened times.
#
# Until it began.
#
# First, it was subtle. The vibrant colors of the nebula around Aethelgard seemed to dull, ever so slightly. Then, the liquid starlight rivers began to flow with less vigor, their glow dimming. Within the Grand Cosmic Archive, data streams flickered, and some of the more ancient memories began to fray, like worn tapestries losing their threads.
#
# The lead archivist, a venerable Aethelan named Luminara, whose light-form pulsed with the steady, calm rhythm of a thousand suns, was the first to recognize the truth in the prophecy. Her own vast memory, usually a crystal-clear reservoir of galactic history, now felt like a shallow, troubled pool.
#
# "The Great Silence is upon us," Luminara announced to the Council of Elders, her light-patterns somber and urgent. "A wave of entropic energy is sweeping through the cosmos, consuming light, disrupting quantum fields, and severing the very threads of memory that bind reality."
#
# Panic rippled through Aethelgard. Their essence was light; their existence was knowledge. To lose either was to cease to be.
#
# The solution, Luminara knew, lay not in advanced weaponry or defensive shields, for how could one fight the absence of being? It lay in the heart of their own legends: the "Star-Seed," a mythical artifact said to contain the primordial spark of creation, capable of re-igniting dying stars and restoring cosmic harmony. It was believed to have been entrusted to the care of a lost civilization, long vanished from galactic records.
#
# With dwindling time and courage born of desperation, Luminara assembled a small team. Among them was a young Aethelan named Kael, whose light-form was still bright and unburdened by ancient fears. Kael possessed a unique gift: an innate ability to perceive and interpret subtle shifts in cosmic energy, a talent akin to reading the silent language of the universe.
#
# Their quest began. They piloted a star-ship woven from solidified light, powered by harmonized stardust, into the ever-darkening void. Kael guided them, interpreting faint energy trails that seemed to whisper of forgotten pathways. They navigated through nebulae turned to shadow, past silent, lifeless planets, and through fields of cosmic debris that had once been vibrant star systems. The encroaching Silence tested their very essence, threatening to absorb their light, to erase their memories of Aethelgard, of their mission, of themselves.
#
# Kael fought against the mental intrusion, focusing on the faint, almost imperceptible echoes of existence that still vibrated through the cosmic ether. His unique gift allowed him to bypass the Silence's attempts to sever his connection to the universal memory, letting him glimpse fleeting images of the lost civilization, a people of crystalline structures and sonic architecture, called the "Harmonites."
#
# Following these ghostly echoes, they finally arrived at a rogue planet, cloaked in perpetual twilight, orbiting a black hole at the edge of known space. It was a world of shattered cities and silent, towering structures, frozen in time.
#
# Within the ruins of the Harmonites' grand temple, Kael found it. Not a physical object in the traditional sense, but a chamber radiating an incredible, focused light. At its center, suspended in a field of pure energy, pulsed a tiny, incandescent orb – the Star-Seed. It was not merely light; it was *potential*, the unformed essence of creation, humming with a silent, profound song.
#
# But the Great Silence had reached even this sanctuary. Spectral tendrils of darkness coiled around the Star-Seed, trying to smother its brilliance.
#
# Luminara knew what had to be done. The Harmonites had understood that true power lay in resonance, in the perfect harmonic alignment of universal energies. The Star-Seed couldn't be simply "activated"; it had to be *sung* into being, its primordial note amplified by a consciousness capable of true cosmic harmony.
#
# It was Kael's moment. Drawing upon his unique gift, he extended his light-form, reaching out to the Star-Seed. He didn't just touch it; he *merged* with its essence, feeling the primordial rhythm of creation flow into his being. Then, Kael began to sing.
#
# Not with a voice, but with pure, unadulterated light-patterns, complex frequencies that wove together the lost memories of the Harmonites, the wisdom of the Aethelans, the echoes of every star that had ever shone. His song was a beacon, a defiant pulse of existence against the encroaching void.
#
# The Star-Seed responded, its light flaring. The spectral tendrils of darkness shrieked and recoiled, unable to withstand the overwhelming harmony. The light expanded, pouring out of the chamber, out of the planet, and into the cosmic void.
#
# The Great Silence did not simply vanish; it was *transformed*. The entropic energy, once a destructive force, was re-harmonized, becoming a vibrant, fertile cosmic dust, pregnant with the promise of new stars. The dimmed nebula around Aethelgard flared back to life, brighter than before. The rivers of liquid starlight flowed with renewed vigor, and the Grand Cosmic Archive hummed with the restored memories of a million worlds.
#
# Kael returned to Aethelgard, no longer merely a young archivist, but a legend, his light-form now carrying the indelible echo of the Star-Seed's song. Aethelgard thrived once more, its light a testament not just to its own resilience, but to the enduring power of memory, harmony, and the unyielding spark of creation that forever dances at the heart of the distant galaxy. And from that day forward, every Aethelan learned to listen, not just with their light-forms, but with their very essence, for the silent song of the universe, a song that promised that even in the deepest darkness, light would always find a way to sing.

# %%
# TODO: Student code for Task 3 – Gemini embeddings and generation


# 1) Embeddings for three sentences

# %% [markdown]
# Print a matrix of it where you can draw the comparisio between all the models

# %%
import torch
import numpy as np
import pandas as pd

# Example sentences
s1 = "I like playing football."
s2 = "I enjoy playing soccer."
sentences = [s1, s2]

# ---------------------------
# 1️⃣ Compute BERT embeddings
# ---------------------------
# Assume bert_encode returns a 1D torch tensor
b_embeddings = torch.stack([bert_encode(s) for s in sentences])  # [2, hidden_dim]
b_norm = b_embeddings / b_embeddings.norm(dim=1, keepdim=True)

# For comparison, we can use the first sentence embedding as representative
bert_vec = b_norm[0]  # shape: [hidden_dim]

# ---------------------------
# 2️⃣ Compute Gemini embeddings
# ---------------------------
# Assume gemini_embed returns a 1D NumPy array
g_embeddings = np.stack([gemini_embed(s) for s in sentences])
g_norm = g_embeddings / np.linalg.norm(g_embeddings, axis=1, keepdims=True)
gemini_vec = torch.from_numpy(g_norm[0]).float()  # take first sentence

# ---------------------------
# 3️⃣ Generate GPT-2 text for each sentence and embed it
# ---------------------------
# Assume gpt_generate returns a string
gpt_text = gpt_generate(s1)

# Embed the GPT-generated text (you can use BERT or Gemini embeddings)
gpt_vec = bert_encode(gpt_text)
gpt_vec = gpt_vec / gpt_vec.norm()  # normalize

# ---------------------------
# 4️⃣ Construct 3x3 similarity matrix
# ---------------------------
vectors = [bert_vec, gemini_vec, gpt_vec]
model_names = ["BERT", "Gemini", "GPT-2"]

sim_matrix = torch.zeros((3,3))

for i in range(3):
    for j in range(3):
        sim_matrix[i,j] = torch.cosine_similarity(vectors[i], vectors[j], dim=0)

# ---------------------------
# 5️⃣ Labeled DataFrame
# ---------------------------
sim_df = pd.DataFrame(sim_matrix.numpy(), index=model_names, columns=model_names)

print("=== Cross-Model Similarity Matrix ===")
print(sim_df)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === Cross-Model Similarity Matrix ===
#             BERT    Gemini     GPT-2
# BERT    1.000000  0.087568  0.817321
# Gemini  0.087568  1.000000  0.100768
# GPT-2   0.817321  0.100768  1.000000

# %%
import torch
import numpy as np
import pandas as pd

# --------------------------------------------------------
# Your functions (already correct)
# --------------------------------------------------------

def bert_encode(sentence: str):
    tokens = bert_tokenizer(sentence, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        out = bert_model(**tokens)
    # CLS embedding
    return out.last_hidden_state[:, 0, :].squeeze(0)  # shape: [hidden_dim]

def gpt_generate(prompt: str, max_length: int = 40):
    tokens = gpt_tokenizer(prompt, return_tensors="pt")
    out_ids = gpt_model.generate(
        **tokens, max_length=max_length, do_sample=False
    )
    return gpt_tokenizer.decode(out_ids[0], skip_special_tokens=True)

def gemini_embed(sentence: str):
    return genai.embed_content(
        model="models/text-embedding-004",
        content=sentence
    )["embedding"]  # numpy list

def gemini_generate(prompt: str):
    resp = gemini_model.generate_content(prompt)
    return resp.text

# --------------------------------------------------------
# 1. Example sentences
# --------------------------------------------------------

s1 = "I love AI."
s2 = "AI is lovely"
sentences = [s1, s2]

# --------------------------------------------------------
# 2. BERT embeddings
# --------------------------------------------------------

bert_emb = torch.stack([bert_encode(s) for s in sentences])   # [2, hidden]
bert_emb_norm = bert_emb / bert_emb.norm(dim=1, keepdim=True)
bert_vec = bert_emb_norm[0]  # use sentence 1

# --------------------------------------------------------
# 3. Gemini embeddings → convert to torch
# --------------------------------------------------------

gemini_emb = np.stack([gemini_embed(s) for s in sentences])   # [2, hidden]
gemini_emb_norm = gemini_emb / np.linalg.norm(gemini_emb, axis=1, keepdims=True)
gemini_vec = torch.tensor(gemini_emb_norm[0], dtype=torch.float32)

# --------------------------------------------------------
# 4. GPT-2 generation → BERT embedding
# --------------------------------------------------------

gpt_output_text = gpt_generate(s1)
gpt_vec = bert_encode(gpt_output_text)
gpt_vec = gpt_vec / gpt_vec.norm()

# --------------------------------------------------------
# 5. Build 3×3 similarity matrix
# --------------------------------------------------------

vectors = [bert_vec, gemini_vec, gpt_vec]
names = ["BERT", "Gemini", "GPT-2"]

sim_matrix = torch.zeros((3, 3))

for i in range(3):
    for j in range(3):
        sim_matrix[i, j] = torch.cosine_similarity(vectors[i], vectors[j], dim=0)

# --------------------------------------------------------
# 6. Build DataFrame
# --------------------------------------------------------

sim_df = pd.DataFrame(sim_matrix.numpy(), index=names, columns=names)

print("\n=== CROSS-MODEL SIMILARITY MATRIX ===\n")
print(sim_df)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# === CROSS-MODEL SIMILARITY MATRIX ===
#
#             BERT    Gemini     GPT-2
# BERT    1.000000  0.009073  0.832366
# Gemini  0.009073  1.000000  0.024357
# GPT-2   0.832366  0.024357  1.000000
